# %% [markdown]
# # Corrected Section 7 cost estimation
#
# This notebook calls `Total_cost_estimation.py`, which performs the exhaustive optimization while keeping the manuscript's original Toffoli-depth objective. The corrected implementation uses $k=2n-r$, the determinant-consistent modified GSA, the original-CBD residual moments $E[X^2]=1$ for $\eta=2$ and $E[X^2]=1.5$ for $\eta=3$, and the revised constant-division/bit-length formulas. Full TD, TC, GD, and GC values are evaluated once at each selected optimum. Checkpoints are formula-versioned so results produced by older equations cannot be silently reused.

# %%
from Total_cost_estimation import (
    MODEL_VERSION,
    cbd_second_moment,
    evaluate_candidate,
    run_cost_estimation,
)

print("formula version:", MODEL_VERSION)
print("CBD moments:", {eta: cbd_second_moment(eta) for eta in (2, 3)})
# Out:
# formula version: 2026-08-15-k-dimension-gsa-det-cbd-moment-v1
# CBD moments: {2: 1.0, 3: 1.5}

# %% [markdown]
# ## Optional one-point check
#
# This evaluates a single candidate without starting the exhaustive sweep.

# %%
evaluate_candidate(n=512, r=89, block_size=407)
# Out:
# {'model_version': '2026-08-15-k-dimension-gsa-det-cbd-moment-v1',
#  'n': 512,
#  'r': 89,
#  'reduced_dimension': 935,
#  'block_size': 407,
#  'gsa_tail_dimension': 934,
#  'delta': 1.003934459141254,
#  'prob_log2': -34.94227569381552,
#  'T_red_log2': 150.84074300933818,
#  'T_hyb_log2': 142.60956965555596,
#  'total_cost_log2': 185.78781187297514}

# %% [markdown]
# ## Exhaustive computation
#
# The search is resumable. Set `workers` to a suitable number for the machine. Each integer BKZ block size $\beta=91,\ldots,k$ satisfying the modified-GSA conditions is evaluated, so parallel execution changes only runtime.

# %%
results = run_cost_estimation(
    n_list=(256, 512, 768, 1024),
    output_dir="section7_results",
    workers=1,  # increase for parallel execution
)
results
# Out:
# n=256: completed r=1 (1/255)
# n=256: completed r=2 (2/255)
# n=256: completed r=3 (3/255)
# n=256: completed r=4 (4/255)
# n=256: completed r=5 (5/255)
# n=256: completed r=6 (6/255)
# n=256: completed r=7 (7/255)
# n=256: completed r=8 (8/255)
# n=256: completed r=9 (9/255)
# n=256: completed r=10 (10/255)
# n=256: completed r=11 (11/255)
# n=256: completed r=12 (12/255)
# n=256: completed r=13 (13/255)
# n=256: completed r=14 (14/255)
# n=256: completed r=15 (15/255)
# n=256: completed r=16 (16/255)
# n=256: completed r=17 (17/255)
# n=256: completed r=18 (18/255)
# n=256: completed r=19 (19/255)
# n=256: completed r=20 (20/255)
# n=256: completed r=21 (21/255)
# n=256: completed r=22 (22/255)
# n=256: completed r=23 (23/255)
# n=256: completed r=24 (24/255)
# n=256: completed r=25 (25/255)
# n=256: completed r=26 (26/255)
# n=256: completed r=27 (27/255)
# n=256: completed r=28 (28/255)
# n=256: completed r=29 (29/255)
# n=256: completed r=30 (30/255)
# ...
