# %%
import math
import numpy as np
import pandas as pd

# %%
# Given distribution values
values = [1, np.cbrt(4) ** 2, np.cbrt(6) ** 2, np.cbrt(4) ** 2, 1]

# Corresponding d values (-2, -1, 0, 1, 2)
d_values = [-2, -1, 0, 1, 2]

# Calculate normalization constant T (sum of values)
T = sum(values)

# Normalize the values to get the probability distribution
prob_distribution = [x / T for x in values]

# Calculate the expectation of norm (|d|)
expectation_vl_norm_eta_2 = sum(prob * abs(d) * abs(d) for prob, d in zip(prob_distribution, d_values))
print(expectation_vl_norm_eta_2)

# Output the probability distribution and expectation
for i, prob in enumerate(prob_distribution, start=-2):
    print(f"P(d_{i}) = {prob:.4f}")
# Out:
# 1.2608948097255643
# P(d_-2) = 0.0967
# P(d_-1) = 0.2437
# P(d_0) = 0.3193
# P(d_1) = 0.2437
# P(d_2) = 0.0967

# %%
# Given distribution values
values = [1, np.cbrt(6) ** 2, np.cbrt(15) ** 2, np.cbrt(20) ** 2, np.cbrt(15) ** 2, np.cbrt(6) ** 2, 1]
# values = [1, np.cbrt(6), np.cbrt(15), np.cbrt(20), np.cbrt(15), np.cbrt(6), 1]

d_values = [-3, -2, -1, 0, 1, 2, 3]

# Calculate normalization constant T (sum of values)
T = sum(values)

# Normalize the values to get the probability distribution
prob_distribution = [x / T for x in values]

# Calculate the expectation of norm (|d|)
expectation_vl_norm_eta_3 = sum(prob * abs(d) * abs(d) for prob, d in zip(prob_distribution, d_values))
print(expectation_vl_norm_eta_3)

# Output the probability distribution and expectation
for i, prob in enumerate(prob_distribution, start=-3):
    print(f"P(d_{i}) = {prob:.4f}")
# Out:
# 2.010917525591277
# P(d_-3) = 0.0355
# P(d_-2) = 0.1174
# P(d_-1) = 0.2162
# P(d_0) = 0.2619
# P(d_1) = 0.2162
# P(d_2) = 0.1174
# P(d_3) = 0.0355

# %%
def calculate_delta(b):
    delta = (((math.pi * b)**(1 / b) * b) / (2 * math.pi * math.e))**(1 / (2 * (b - 1)))
    # print(f"b, delta: {b}, {delta}")
    return delta

def calculate_reduction_runtime_log2(b, d, r):
    n = d-r
    delta = calculate_delta(b)
    rho_log2 = math.log2(math.ceil((n**2 / b**2) * math.log2(n))) # need to make it precise in the case b does not divide others
    T_svp_log2 = 0.265*b+16.4 #2**(0.265*b+16.4)
    runtime_log2 = rho_log2 + math.log2(n) + T_svp_log2
    return runtime_log2, delta

# %%
from scipy.special import beta
from scipy.integrate import quad
import Q_Toffoli_cost as QTC

def compute_probability_log2(R, v_norm, d, r):
    """
    Compute the probability 'p' based on the given formula.
    
    Parameters:
        R (list or array): List of R_i values
        v_norm (float): Norm of vector ||v_l||
        d (int): Dimension parameter
        r (int): guessing number
        
    Returns:
        float: Approximation of the probability 'p'
    """
    def integrand(t, power):
        """Integrand function: (1 - t^2)^power"""
        return (1 - t**2)**power
    
    # Initialize probability product
    p = 1.0
    p_log2 = 0
    beta_value = beta((d - r - 1) / 2, 1 / 2)  # Precompute Beta function

    for i in range(d - r):
        r_i = R[i] / (2 * v_norm)
        max_limit = max(-r_i, -1)
        power = (d - r - 3) / 2
        
        integral_value, _ = quad(integrand, -1, max_limit, args=(power))

        term = 1 - (2 / beta_value) * integral_value
        term_log2 = math.log2(term)

        p *= term
        p_log2 += term_log2
    
    return p_log2

def calculate_k(b, delta, d):
    """
    Calculate the value of k based on the formula:
    k = min(floor(sqrt(b / log_q_delta)), d)
    """
    # print(math.log(delta, q))
    return min(math.floor(math.sqrt(b / math.log(delta, q))), d)

def calculate_R_i(i, d, k, q, delta, b):
    """
    Calculate the value of R_i based on the given conditions:
    R_i = q, if i <= d - k
          delta^(-2 * (i - (d - k) - 1) + k) * q^(k - b / k), otherwise
    """
    if i <= d - k:
        return q
    else:
        exponent = -2 * (i - (d - k) - 1) + k
        # print(exponent)

        log2_delta = math.log2(delta)
        log2_q = math.log2(q)

        # Calculate log2 of the value
        log2_value = exponent * log2_delta + ((k - b) / k) * log2_q
        
        return 2**log2_value
    
def calculate_quantum_depth_count_log2(n, r, log2_L_j_list):
    depth_const, cost_const = QTC.compute_Toffoli_depth_and_cost(n, r, log2_L_j_list)
    # print(f"Depth const: {depth_const}, Cost const: {cost_const}")
    if n == 512:
        log2_depth = 1.302 * r + depth_const
        log2_count = 1.302 * r + cost_const
    elif n == 768:
        log2_depth = 1.108 * r + depth_const
        log2_count = 1.108 * r + cost_const
    elif n == 1024:
        log2_depth = 1.108 * r + depth_const
        log2_count = 1.108 * r + cost_const
    else:
        raise ValueError("Invalid value for n. Supported values are 512, 768, 1024.")
    
    return log2_depth, log2_count

def log2_sum_stable(x_prime, y_prime):
    max_prime = max(x_prime, y_prime)
    min_prime = min(x_prime, y_prime)
    result = max_prime + math.log2(1 + 2**(min_prime - max_prime))
    return result

# %%
import os
import datetime

# Ensure the calculate and utility functions are implemented
# calculate_reduction_runtime_log2, calculate_k, calculate_R_i,
# compute_probability_log2, calculate_quantum_depth_log2,
# log2_sum_stable

q = 3329  # Replace with actual value
n_list = [512, 768, 1024]
vl_expect_list = [expectation_vl_norm_eta_3, expectation_vl_norm_eta_2, expectation_vl_norm_eta_2]

# Create a directory to store the results that is with today's date
output_dir = f"result_with_cost{datetime.datetime.now().strftime('%Y-%m-%d')}"
os.makedirs(output_dir, exist_ok=True)  # Create the directory if it doesn't exist

for idx in range(3):
    n = n_list[idx]
    vl_expect_each = vl_expect_list[idx]
    d = 2 * n  # -1 because the last 1 entry is skipped

    # all_result_fn = os.path.join(output_dir, f"all_cost_log2_results_{n}.csv")
    best_result_fn = os.path.join(output_dir, f"best_cost_log2_results_{n}.csv")

    # Load existing results if files exist
    # if os.path.exists(all_result_fn):
    #     all_results_df = pd.read_csv(all_result_fn)
    # else:
    #     all_results_df = pd.DataFrame()

    if os.path.exists(best_result_fn):
        best_results_df = pd.read_csv(best_result_fn)
    else:
        best_results_df = pd.DataFrame()

    previous_cost = float('inf')  # Track previous cost
    increase_count = 0  # Track number of consecutive increases in cost

    for r in range(1, n + 1):
        # Skip if r is already processed
        if not best_results_df.empty and r in best_results_df['r'].values:
            continue

        vl_norm = np.sqrt(vl_expect_each * (d - r))
        d_ab = 2 * n - r
        a = n
        b = n - r

        best_cost = float('inf')  # Initialize to a very high value
        best_details = None  # To store the best cost details

        for block_size in range(90, d-r+1): # b needs to be bigger than 90 to apply BDGL sieve cost estimation. In addition, blocksize was chosen to be bigger than 90 expreimentally.
            T_red_log2, delta = calculate_reduction_runtime_log2(block_size, d, r)

            if delta <= 1:
                continue

            k = calculate_k(b, delta, d_ab)

            if k >= d_ab or k <= b:
                continue

            R_values = [calculate_R_i(i, d_ab, k, q, delta, b) for i in range(1, d_ab + 1)]
            prob_log2 = compute_probability_log2(R_values, vl_norm, d, r)
            log2_L_j_list = [math.log2(R_values[j - 1]) for j in range(1, d_ab + 1)]


            T_hyb_log2, count_hyp_log2 = calculate_quantum_depth_count_log2(n, r, log2_L_j_list)

            cost_log2_hyp = T_hyb_log2 - prob_log2
            cost_log2_red = T_red_log2 - prob_log2

            total_cost_log2 = log2_sum_stable(cost_log2_hyp, cost_log2_red)

            # Save current result
            current_result = {
                "n": n,
                "r": r,
                "block_size": block_size,
                "total_cost_log2": total_cost_log2,
                "T_hyb_log2": T_hyb_log2,
                "T_red_log2": T_red_log2,
                "prob_log2": prob_log2,
                "delta": delta,
                "k": k,
                "Toffoli_cost_log2_hyp": cost_log2_hyp,
                "R_values": R_values
            }
            # all_results_df = pd.concat([all_results_df, pd.DataFrame([current_result])], ignore_index=True)

            # Check if this is the best cost so far
            if total_cost_log2 < best_cost:
                best_cost = total_cost_log2
                best_details = current_result

        # Save the best result for this r
        if best_details:
            best_results_df = pd.concat([best_results_df, pd.DataFrame([best_details])], ignore_index=True)

        # # Check if cost increased
        # if best_cost > previous_cost:
        #     increase_count += 1
        # else:
        #     increase_count = 0

        # Update previous cost
        previous_cost = best_cost

        # Stop if cost has increased for 5 consecutive iterations
        # if increase_count >= 5:
        #     print(f"Stopping early for n={n} after r={r} due to consecutive cost increases.")
        #     break

        # Save results to CSV after each r
        # all_results_df.to_csv(all_result_fn, index=False)
        best_results_df.to_csv(best_result_fn, index=False)

        # print(f"Results for r={r} saved to {all_result_fn} and {best_result_fn}")
        print(f"Results for r={r} saved to {best_result_fn}")

print("All computations completed.")
# Out:
# Results for r=1 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=2 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=3 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=4 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=5 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=6 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=7 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=8 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=9 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=10 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=11 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=12 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=13 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=14 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=15 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=16 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=17 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=18 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=19 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=20 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=21 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=22 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=23 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=24 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=25 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=26 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=27 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=28 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=29 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=30 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=31 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=32 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=33 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=34 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=35 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=36 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=37 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=38 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=39 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=40 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=41 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=42 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=43 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=44 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=45 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=46 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=47 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=48 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=49 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=50 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=51 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=52 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=53 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=54 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=55 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=56 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=57 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=58 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=59 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=60 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=61 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=62 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=63 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=64 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=65 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=66 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=67 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=68 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=69 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=70 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=71 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=72 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=73 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=74 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=75 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=76 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=77 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=78 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=79 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=80 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=81 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=82 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=83 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=84 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=85 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=86 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=87 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=88 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=89 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=90 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=91 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=92 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=93 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=94 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=95 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=96 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=97 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=98 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=99 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=100 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=101 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=102 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=103 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=104 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=105 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=106 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=107 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=108 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=109 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=110 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=111 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=112 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=113 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=114 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=115 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=116 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=117 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=118 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=119 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=120 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=121 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=122 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=123 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=124 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=125 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=126 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=127 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=128 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=129 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=130 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=131 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=132 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=133 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=134 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=135 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=136 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=137 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=138 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=139 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=140 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=141 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=142 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=143 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=144 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=145 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=146 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=147 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=148 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=149 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=150 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=151 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=152 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=153 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=154 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=155 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=156 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=157 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=158 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=159 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=160 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=161 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=162 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=163 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=164 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=165 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=166 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=167 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=168 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=169 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=170 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=171 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=172 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=173 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=174 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=175 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=176 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=177 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=178 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=179 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=180 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=181 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=182 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=183 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=184 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=185 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=186 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=187 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=188 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=189 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=190 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=191 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=192 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=193 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=194 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=195 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=196 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=197 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=198 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=199 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=200 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=201 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=202 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=203 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=204 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=205 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=206 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=207 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=208 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=209 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=210 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=211 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=212 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=213 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=214 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=215 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=216 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=217 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=218 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=219 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=220 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=221 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=222 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=223 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=224 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=225 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=226 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=227 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=228 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=229 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=230 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=231 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=232 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=233 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=234 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=235 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=236 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=237 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=238 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=239 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=240 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=241 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=242 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=243 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=244 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=245 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=246 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=247 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=248 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=249 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=250 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=251 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=252 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=253 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=254 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=255 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=256 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=257 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=258 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=259 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=260 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=261 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=262 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=263 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=264 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=265 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=266 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=267 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=268 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=269 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=270 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=271 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=272 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=273 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=274 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=275 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=276 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=277 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=278 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=279 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=280 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=281 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=282 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=283 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=284 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=285 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=286 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=287 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=288 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=289 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=290 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=291 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=292 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=293 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=294 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=295 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=296 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=297 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=298 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=299 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=300 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=301 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=302 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=303 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=304 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=305 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=306 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=307 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=308 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=309 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=310 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=311 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=312 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=313 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=314 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=315 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=316 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=317 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=318 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=319 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=320 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=321 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=322 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=323 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=324 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=325 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=326 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=327 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=328 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=329 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=330 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=331 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=332 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=333 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=334 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=335 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=336 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=337 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=338 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=339 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=340 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=341 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=342 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=343 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=344 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=345 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=346 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=347 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=348 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=349 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=350 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=351 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=352 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=353 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=354 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=355 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=356 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=357 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=358 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=359 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=360 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=361 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=362 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=363 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=364 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=365 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=366 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=367 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=368 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=369 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=370 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=371 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=372 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=373 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=374 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=375 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=376 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=377 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=378 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=379 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=380 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=381 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=382 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=383 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=384 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=385 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=386 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=387 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=388 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=389 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=390 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=391 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=392 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=393 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=394 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=395 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=396 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=397 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=398 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=399 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=400 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=401 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=402 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=403 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=404 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=405 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=406 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=407 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=408 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=409 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=410 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=411 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=412 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=413 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=414 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=415 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=416 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=417 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=418 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=419 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=420 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=421 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=422 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=423 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=424 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=425 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=426 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=427 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=428 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=429 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=430 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=431 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=432 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=433 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=434 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=435 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=436 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=437 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=438 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=439 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=440 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=441 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=442 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=443 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=444 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=445 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=446 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=447 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=448 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=449 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=450 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=451 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=452 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=453 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=454 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=455 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=456 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=457 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=458 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=459 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=460 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=461 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=462 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=463 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=464 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=465 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=466 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=467 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=468 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=469 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=470 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=471 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=472 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=473 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=474 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=475 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=476 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=477 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=478 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=479 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=480 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=481 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=482 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=483 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=484 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=485 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=486 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=487 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=488 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=489 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=490 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=491 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=492 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=493 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=494 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=495 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=496 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=497 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=498 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=499 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=500 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=501 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=502 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=503 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=504 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=505 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=506 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=507 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=508 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=509 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=510 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=511 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=512 saved to result_with_cost2025-07-03\best_cost_log2_results_512.csv
# Results for r=1 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# Results for r=2 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# Results for r=3 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# Results for r=4 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# Results for r=5 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# Results for r=6 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# Results for r=7 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# Results for r=8 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# Results for r=9 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# Results for r=10 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# Results for r=11 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# Results for r=12 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# Results for r=13 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# Results for r=14 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# Results for r=15 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# Results for r=16 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# Results for r=17 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# Results for r=18 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# Results for r=19 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# Results for r=20 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# Results for r=21 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# Results for r=22 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# Results for r=23 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# Results for r=24 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# Results for r=25 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# Results for r=26 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# Results for r=27 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# Results for r=28 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# Results for r=29 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# Results for r=30 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# Results for r=31 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# Results for r=32 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# Results for r=33 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# Results for r=34 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# Results for r=35 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# Results for r=36 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# Results for r=37 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# Results for r=38 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# Results for r=39 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# Results for r=40 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# Results for r=41 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# Results for r=42 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# Results for r=43 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# Results for r=44 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# Results for r=45 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# Results for r=46 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# Results for r=47 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# Results for r=48 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# Results for r=49 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# Results for r=50 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# Results for r=51 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# Results for r=52 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# Results for r=53 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# Results for r=54 saved to result_with_cost2025-07-03\best_cost_log2_results_768.csv
# ...
# Results for r=840 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=841 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=842 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=843 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=844 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=845 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=846 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=847 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=848 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=849 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=850 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=851 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=852 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=853 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=854 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=855 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=856 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=857 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=858 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=859 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=860 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=861 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=862 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=863 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=864 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=865 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=866 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=867 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=868 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=869 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=870 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=871 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=872 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=873 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=874 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=875 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=876 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=877 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=878 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=879 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=880 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=881 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=882 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=883 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=884 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=885 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=886 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=887 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=888 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=889 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=890 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=891 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=892 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=893 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=894 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=895 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=896 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=897 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=898 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=899 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=900 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=901 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=902 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=903 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=904 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=905 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=906 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=907 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=908 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=909 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=910 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=911 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=912 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=913 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=914 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=915 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=916 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=917 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=918 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=919 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=920 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=921 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=922 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=923 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=924 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=925 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=926 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=927 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=928 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=929 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=930 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=931 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=932 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=933 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=934 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=935 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=936 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=937 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=938 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=939 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=940 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=941 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=942 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=943 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=944 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=945 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=946 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=947 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=948 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=949 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=950 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=951 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=952 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=953 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=954 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=955 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=956 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=957 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=958 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=959 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=960 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=961 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=962 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=963 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=964 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=965 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=966 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=967 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=968 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=969 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=970 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=971 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=972 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=973 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=974 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=975 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=976 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=977 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=978 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=979 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=980 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=981 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=982 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=983 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=984 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=985 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=986 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=987 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=988 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=989 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=990 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=991 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=992 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=993 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=994 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=995 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=996 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=997 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=998 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=999 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=1000 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=1001 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=1002 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=1003 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=1004 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=1005 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=1006 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=1007 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=1008 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=1009 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=1010 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=1011 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=1012 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=1013 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=1014 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=1015 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=1016 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=1017 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=1018 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=1019 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=1020 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=1021 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=1022 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=1023 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# Results for r=1024 saved to result_with_cost2025-07-03\best_cost_log2_results_1024.csv
# All computations completed.
